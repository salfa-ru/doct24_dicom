# %%
from processor import LungsAnalyzer
from patologies import Piece
import matplotlib.pyplot as plt
import numpy as np
from lungmask import mask 
import nibabel as nib
import json, os
import SimpleITK as sitk
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.

# %%
# %%time
l_1 = LungsAnalyzer('0011', segmentation=True)
# Out:
# CPU times: total: 797 ms
# Wall time: 1.21 s

# %% [markdown]
# ### Разметка долей легких:

# %%
idx=30
plt.figure(figsize=(15, 15))
for n in np.arange(4, 13):
    plt.subplot(3, 3, n - 3)
    plt.imshow(l_1.images[n * idx], cmap='gray')
    seg_arr = np.ma.masked_where(np.array(l_1.segmentation) == 0, l_1.segmentation)
    plt.imshow(seg_arr[n * idx], alpha=0.5)

# %% [markdown]
# ### Генерация обширного поражения левого легкого COVID-19

# %%
# %%time
params = {"id": "0011", "mode": "gen", "patology": "covid", "segments": [1, 2], "quantity": 2, 'size': 1}
l_1.get_generation(**params)
# Out:
# CPU times: total: 31.2 ms
# Wall time: 1.06 ms
# './data/0011/generation/covid_[1, 2]_2_1.zip'

# %%
fake_path = './data/0011/generation/covid_[1, 2]_2_1'

reader = sitk.ImageSeriesReader()
dicom_names = [f'{fake_path}/{file}' for file in list(os.walk(fake_path))[0][2]]
reader.SetFileNames(dicom_names)
images = reader.Execute()
images = sitk.GetArrayFromImage(images)

# %%
idx=200

plt.figure(figsize=(15, 15))
plt.subplot(1, 2, 1)
plt.imshow(l_1.images[idx], cmap='gray')

plt.subplot(1, 2, 2)
plt.imshow(images[idx], cmap='gray')

plt.show()

# %%
idx=230

plt.figure(figsize=(15, 15))
plt.subplot(1, 2, 1)
plt.imshow(l_1.images[idx], cmap='gray')

plt.subplot(1, 2, 2)
plt.imshow(images[idx], cmap='gray')

plt.show()

# %%
idx=280

plt.figure(figsize=(15, 15))
plt.subplot(1, 2, 1)
plt.imshow(l_1.images[idx], cmap='gray')

plt.subplot(1, 2, 2)
plt.imshow(images[idx], cmap='gray')

plt.show()

# %%
idx=310

plt.figure(figsize=(15, 15))
plt.subplot(1, 2, 1)
plt.imshow(l_1.images[idx], cmap='gray')

plt.subplot(1, 2, 2)
plt.imshow(images[idx], cmap='gray')

plt.show()

# %%
idx=350

plt.figure(figsize=(15, 15))
plt.subplot(1, 2, 1)
plt.imshow(l_1.images[idx], cmap='gray')

plt.subplot(1, 2, 2)
plt.imshow(images[idx], cmap='gray')

plt.show()

# %% [markdown]
# ### Генерация обширного поражения правого легкого COVID-19

# %%
# %%time
params = {"id": "0011", "mode": "gen", "patology": "covid", "segments": [3, 4 ,5], "quantity": 2, 'size': 1}
l_1.get_generation(**params)
# Out:
# Началась генерация.
# Загрузка паталогии.
# Поиск базовой точки. 180 (376, 89)
# Генерация изображений: 191 из 191
# Сохранение.
# CPU times: total: 10min 47s
# Wall time: 11min 1s
# './data/0011/generation/covid_[3, 4, 5]_2_1.zip'

# %%
fake_path = './data/0011/generation/covid_[3, 4, 5]_2_1'

reader = sitk.ImageSeriesReader()
dicom_names = [f'{fake_path}/{file}' for file in list(os.walk(fake_path))[0][2]]
reader.SetFileNames(dicom_names)
images = reader.Execute()
images = sitk.GetArrayFromImage(images)

# %%
idx=180

plt.figure(figsize=(15, 15))
plt.subplot(1, 2, 1)
plt.imshow(l_1.images[idx], cmap='gray')

plt.subplot(1, 2, 2)
plt.imshow(images[idx], cmap='gray')

plt.show()

# %%
idx=210

plt.figure(figsize=(15, 15))
plt.subplot(1, 2, 1)
plt.imshow(l_1.images[idx], cmap='gray')

plt.subplot(1, 2, 2)
plt.imshow(images[idx], cmap='gray')

plt.show()

# %%
idx=250

plt.figure(figsize=(15, 15))
plt.subplot(1, 2, 1)
plt.imshow(l_1.images[idx], cmap='gray')

plt.subplot(1, 2, 2)
plt.imshow(images[idx], cmap='gray')

plt.show()

# %%
idx=290

plt.figure(figsize=(15, 15))
plt.subplot(1, 2, 1)
plt.imshow(l_1.images[idx], cmap='gray')

plt.subplot(1, 2, 2)
plt.imshow(images[idx], cmap='gray')

plt.show()

# %%
idx=330

plt.figure(figsize=(15, 15))
plt.subplot(1, 2, 1)
plt.imshow(l_1.images[idx], cmap='gray')

plt.subplot(1, 2, 2)
plt.imshow(images[idx], cmap='gray')

plt.show()
