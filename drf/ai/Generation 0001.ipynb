# %%
from processor import LungsAnalyzer
from patologies import Piece
import matplotlib.pyplot as plt
import numpy as np
from lungmask import mask 
import nibabel as nib
import json, os
import SimpleITK as sitk
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.

# %%
# %%time
l_1 = LungsAnalyzer('0001', segmentation=True)
# Out:
# CPU times: total: 203 ms
# Wall time: 179 ms

# %% [markdown]
# ### Разметка долей легких:

# %%
idx=30
plt.figure(figsize=(15, 15))
for n in np.arange(4, 13):
    plt.subplot(3, 3, n - 3)
    plt.imshow(l_1.images[n * idx], cmap='gray')
    seg_arr = np.ma.masked_where(np.array(l_1.segmentation) == 0, l_1.segmentation)
    plt.imshow(seg_arr[n * idx], alpha=0.5)

# %% [markdown]
# ### Генерация обширного поражения правого легкого COVID-19

# %%
# %%time
params = {"id": "0001", "mode": "gen", "patology": "covid", "segments": [3, 4, 5], "quantity": 2, 'size': 1}
l_1.get_generation(**params)
# Out:
# Началась генерация.
# Загрузка паталогии.
# Поиск базовой точки. 13 (357, 72)
# Генерация изображений: 19 из 19
# Сохранение.
# CPU times: total: 17.1 s
# Wall time: 18.1 s
# './data/0001/generation/covid_[3, 4, 5]_2_1.zip'

# %%
fake_path = './data/0001/generation/covid_[3, 4, 5]_2_1'

reader = sitk.ImageSeriesReader()
dicom_names = [f'{fake_path}/{file}' for file in list(os.walk(fake_path))[0][2]]
reader.SetFileNames(dicom_names)
images = reader.Execute()
images = sitk.GetArrayFromImage(images)

# %%
idx=16

plt.figure(figsize=(15, 15))
plt.subplot(1, 2, 1)
plt.imshow(l_1.images[idx], cmap='gray')

plt.subplot(1, 2, 2)
plt.imshow(images[idx], cmap='gray')

plt.show()

# %%
idx=20

plt.figure(figsize=(15, 15))
plt.subplot(1, 2, 1)
plt.imshow(l_1.images[idx], cmap='gray')

plt.subplot(1, 2, 2)
plt.imshow(images[idx], cmap='gray')

plt.show()

# %%
idx=24

plt.figure(figsize=(15, 15))
plt.subplot(1, 2, 1)
plt.imshow(l_1.images[idx], cmap='gray')

plt.subplot(1, 2, 2)
plt.imshow(images[idx], cmap='gray')

plt.show()

# %%
idx=28

plt.figure(figsize=(15, 15))
plt.subplot(1, 2, 1)
plt.imshow(l_1.images[idx], cmap='gray')

plt.subplot(1, 2, 2)
plt.imshow(images[idx], cmap='gray')

plt.show()

# %%
idx=30

plt.figure(figsize=(15, 15))
plt.subplot(1, 2, 1)
plt.imshow(l_1.images[idx], cmap='gray')

plt.subplot(1, 2, 2)
plt.imshow(images[idx], cmap='gray')

plt.show()

# %% [markdown]
# ### Генерация единичного поражения верхней доли правого легкого COVID-19

# %%
# %%time
params = {"id": "0001", "mode": "gen", "patology": "covid", "segments": [5], "quantity": 1, 'size': 1}
l_1.get_generation(**params)
# Out:
# Началась генерация.
# Загрузка паталогии.
# Поиск базовой точки. 8 [345 120]
# Генерация изображений: 15 из 15
# Сохранение.
# CPU times: total: 11.6 s
# Wall time: 11.7 s
# './data/0001/generation/covid_[5]_1_1.zip'

# %%
fake_path = './data/0001/generation/covid_[5]_1_1'

reader = sitk.ImageSeriesReader()
dicom_names = [f'{fake_path}/{file}' for file in list(os.walk(fake_path))[0][2]]
reader.SetFileNames(dicom_names)
images = reader.Execute()
images = sitk.GetArrayFromImage(images)

# %%
idx=10

plt.figure(figsize=(15, 15))
plt.subplot(1, 2, 1)
plt.imshow(l_1.images[idx], cmap='gray')

plt.subplot(1, 2, 2)
plt.imshow(images[idx], cmap='gray')

plt.show()

# %%
idx=12

plt.figure(figsize=(15, 15))
plt.subplot(1, 2, 1)
plt.imshow(l_1.images[idx], cmap='gray')

plt.subplot(1, 2, 2)
plt.imshow(images[idx], cmap='gray')

plt.show()

# %%
idx=14

plt.figure(figsize=(15, 15))
plt.subplot(1, 2, 1)
plt.imshow(l_1.images[idx], cmap='gray')

plt.subplot(1, 2, 2)
plt.imshow(images[idx], cmap='gray')

plt.show()

# %%
idx=18

plt.figure(figsize=(15, 15))
plt.subplot(1, 2, 1)
plt.imshow(l_1.images[idx], cmap='gray')

plt.subplot(1, 2, 2)
plt.imshow(images[idx], cmap='gray')

plt.show()

# %%
idx=20

plt.figure(figsize=(15, 15))
plt.subplot(1, 2, 1)
plt.imshow(l_1.images[idx], cmap='gray')

plt.subplot(1, 2, 2)
plt.imshow(images[idx], cmap='gray')

plt.show()

# %% [markdown]
# ### Генерация единичного поражения нижней доли левого легкого COVID-19

# %%
# %%time
params = {"id": "0001", "mode": "gen", "patology": "covid", "segments": [1], "quantity": 1, 'size': 1}
l_1.get_generation(**params)
# Out:
# Началась генерация.
# Загрузка паталогии.
# Поиск базовой точки. 25 [148 310]
# Генерация изображений: 9 из 9
# Сохранение.
# CPU times: total: 10.8 s
# Wall time: 11 s
# './data/0001/generation/covid_[1]_1_1.zip'

# %%
fake_path = './data/0001/generation/covid_[1]_1_1'

reader = sitk.ImageSeriesReader()
dicom_names = [f'{fake_path}/{file}' for file in list(os.walk(fake_path))[0][2]]
reader.SetFileNames(dicom_names)
images = reader.Execute()
images = sitk.GetArrayFromImage(images)

# %%
idx=26

plt.figure(figsize=(15, 15))
plt.subplot(1, 2, 1)
plt.imshow(l_1.images[idx], cmap='gray')

plt.subplot(1, 2, 2)
plt.imshow(images[idx], cmap='gray')

plt.show()

# %%
idx=27

plt.figure(figsize=(15, 15))
plt.subplot(1, 2, 1)
plt.imshow(l_1.images[idx], cmap='gray')

plt.subplot(1, 2, 2)
plt.imshow(images[idx], cmap='gray')

plt.show()

# %%
idx=28

plt.figure(figsize=(15, 15))
plt.subplot(1, 2, 1)
plt.imshow(l_1.images[idx], cmap='gray')

plt.subplot(1, 2, 2)
plt.imshow(images[idx], cmap='gray')

plt.show()

# %%
idx=31

plt.figure(figsize=(15, 15))
plt.subplot(1, 2, 1)
plt.imshow(l_1.images[idx], cmap='gray')

plt.subplot(1, 2, 2)
plt.imshow(images[idx], cmap='gray')

plt.show()
